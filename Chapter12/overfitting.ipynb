# %%
import numpy as np

# %%
np.random.seed(42)
x1=np.random.random_sample((2000,5))
y=[[1,0]]
y1=np.repeat(y,2000,axis=0)

# %%
np.random.seed(0)
x2=np.random.random_sample((2000,5))*-1
y=[[0,1]]
y2=np.repeat(y,2000,axis=0)

# %%
x_new=np.append(x1,x2,axis=0)

# %%
x_new.shape
# Out:
# (4000, 5)

# %%
y_new=np.append(y1,y2,axis=0)

# %%
y_new.shape
# Out:
# (4000, 2)

# %%
np.random.seed(5)
x1_badsamples = np.random.random_sample((200,5))
x2_badsamples = np.random.random_sample((200,5))*-1

y1_badsamples = np.repeat([[0,1]],200,axis=0)
y2_badsamples = np.repeat([[1,0]],200,axis=0)

# %%
x_badsamples = np.append(x1_badsamples,x2_badsamples,axis=0)
y_badsamples = np.append(y1_badsamples,y2_badsamples,axis=0)

# %%
final_x=np.append(x_new,x_badsamples,axis=0)
final_y=np.append(y_new,y_badsamples,axis=0)

# %%
np.random.seed(10)
x1_test = np.random.random_sample((200,5))
x2_test = np.random.random_sample((200,5))*-1

y1_test = np.repeat([[1,0]],200,axis=0)
y2_test = np.repeat([[0,1]],200,axis=0)

# %%
test_x=np.append(x1_test,x2_test,axis=0)
test_y=np.append(y1_test,y2_test,axis=0)

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.initializers import RandomUniform
from keras.regularizers import l2
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
model = Sequential()
model.add(Dense(1000, input_dim=5, kernel_initializer='normal',activation='relu'))
model.add(Dense(500,  kernel_initializer='normal',activation='relu'))
model.add(Dense(100,  kernel_initializer='normal',activation='relu'))

model.add(Dense(2,  activation='softmax'))
tensorboard = TensorBoard(log_dir = "logs/tensor_1")
# Compile mo
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(final_x,final_y, validation_data=(test_x,test_y), epochs=1000, batch_size=5000, verbose=1,callbacks=[tensorboard])
# Out:
# Train on 4400 samples, validate on 400 samples
# Epoch 1/1000
# 4400/4400 [==============================] - 0s 29us/step - loss: 0.7060 - acc: 0.1782 - val_loss: 0.1395 - val_acc: 1.0000
# Epoch 2/1000
# 4400/4400 [==============================] - 0s 6us/step - loss: 0.3304 - acc: 0.9091 - val_loss: 0.0580 - val_acc: 1.0000
# Epoch 3/1000
# 4400/4400 [==============================] - 0s 6us/step - loss: 0.5483 - acc: 0.9091 - val_loss: 0.0415 - val_acc: 1.0000
# Epoch 4/1000
# 4400/4400 [==============================] - 0s 7us/step - loss: 0.3881 - acc: 0.9091 - val_loss: 0.6452 - val_acc: 0.5000
# Epoch 5/1000
# 4400/4400 [==============================] - 0s 6us/step - loss: 0.6772 - acc: 0.5000 - val_loss: 0.1889 - val_acc: 1.0000
# Epoch 6/1000
# 4400/4400 [==============================] - 0s 6us/step - loss: 0.4510 - acc: 0.9091 - val_loss: 0.1132 - val_acc: 1.0000
# Epoch 7/1000
# ...

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_1')

# %%
from keras.initializers import RandomUniform
from keras.regularizers import l2
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(1000, input_dim=5, kernel_initializer='normal',kernel_regularizer=l2(0.01),activation='relu'))
model.add(Dense(500,  kernel_initializer='normal',kernel_regularizer=l2(0.01),activation='relu'))
model.add(Dense(100,  kernel_initializer='normal',kernel_regularizer=l2(0.01),activation='relu'))

model.add(Dense(2,  activation='softmax'))
tensorboard = TensorBoard(log_dir = "logs/tensor_2")
# Compile mo
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(final_x,final_y, validation_data=(test_x,test_y), epochs=1000, batch_size=5000, verbose=1,callbacks=[tensorboard])

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_2')

# %%
from keras.regularizers import l1
from keras import backend as K
K.clear_session()
model = Sequential()
model.add(Dense(1000, input_dim=5, kernel_initializer='normal',kernel_regularizer=l1(0.001),activation='relu'))
model.add(Dense(500,  kernel_initializer='normal',kernel_regularizer=l1(0.001),activation='relu'))
model.add(Dense(100,  kernel_initializer='normal',kernel_regularizer=l1(0.001),activation='relu'))

model.add(Dense(2,  activation='softmax'))
tensorboard = TensorBoard(log_dir = "logs/tensor_3")
# Compile mo
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(final_x,final_y, validation_data=(test_x,test_y), epochs=1000, batch_size=5000, verbose=1,callbacks=[tensorboard])

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_3')

# %%
from keras import backend as K
K.clear_session()
model = Sequential()
model.add(Dense(1000, input_dim=5, kernel_initializer='normal',activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(500,  kernel_initializer='normal',activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(100,  kernel_initializer='normal',activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2,  activation='softmax'))
tensorboard = TensorBoard(log_dir = "logs/tensor_4")
# Compile mo
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(final_x,final_y, validation_data=(test_x,test_y), epochs=1000, batch_size=5000, verbose=1,callbacks=[tensorboard])

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_4')

# %%
# !pip install tensorboard
# Out:
# ...
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from keras.datasets import mnist

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import np_utils

# %%
num_pixels = X_train.shape[1] * X_train.shape[2]
X_train = X_train.reshape(X_train.shape[0], num_pixels).astype('float32')
X_test = X_test.reshape(X_test.shape[0], num_pixels).astype('float32')

# %%
# one hot encode outputs
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)
num_classes = y_test.shape[1]

# %%
from keras.initializers import RandomUniform
from keras.regularizers import l2
from keras.optimizers import Adam
model = Sequential()
model.add(Dense(1000, input_dim=num_pixels, kernel_initializer='normal',activation='tanh'))
model.add(Dense(500,  kernel_initializer='normal',activation='tanh'))
model.add(Dense(250,  kernel_initializer='normal',activation='tanh'))
model.add(Dense(100,  kernel_initializer='normal',activation='tanh'))

model.add(Dense(num_classes,  activation='softmax'))
# Compile model
adam = Adam(lr=0.001)
tensorboard = TensorBoard(log_dir = "logs/tensor_5")
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, batch_size=60000,  verbose=1,callbacks=[tensorboard])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/500
# 60000/60000 [==============================] - 1s 17us/step - loss: 2.4483 - acc: 0.0900 - val_loss: 1.7121 - val_acc: 0.4550
# Epoch 2/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 1.7183 - acc: 0.4476 - val_loss: 1.1305 - val_acc: 0.7314
# Epoch 3/500
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.1466 - acc: 0.7242 - val_loss: 0.8887 - val_acc: 0.7644
# Epoch 4/500
# 60000/60000 [==============================] - 0s 6us/step - loss: 0.9052 - acc: 0.7607 - val_loss: 0.6889 - val_acc: 0.8256
# Epoch 5/500
# 60000/60000 [==============================] - 0s 6us/step - loss: 0.7083 - acc: 0.8177 - val_loss: 0.5888 - val_acc: 0.8487
# Epoch 6/500
# 60000/60000 [==============================] - 0s 6us/step - loss: 0.6075 - acc: 0.8378 - val_loss: 0.5303 - val_acc: 0.8587
# Epoch 7/500
# ...

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_5')

# %%
X_train = X_train/255
X_test = X_test/255

# %%
from keras.layers.normalization import BatchNormalization
model = Sequential()
model.add(Dense(1000, input_dim=num_pixels, kernel_initializer='normal',activation='relu'))
model.add(BatchNormalization())
model.add(Dense(500,  kernel_initializer='normal',activation='relu'))
model.add(BatchNormalization())
model.add(Dense(250,  kernel_initializer='normal',activation='relu'))
model.add(BatchNormalization())
model.add(Dense(100,  kernel_initializer='normal',activation='relu'))
model.add(BatchNormalization())

model.add(Dense(num_classes,  activation='softmax'))
# Compile model
adam = Adam(lr=0.01)
tensorboard = TensorBoard(log_dir = "logs/tensor_6")
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, batch_size=60000, verbose=1,callbacks=[tensorboard])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/500
# 60000/60000 [==============================] - 1s 23us/step - loss: 3.0608 - acc: 0.1328 - val_loss: 1.0876 - val_acc: 0.6312
# Epoch 2/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 1.0790 - acc: 0.6424 - val_loss: 0.6554 - val_acc: 0.7906
# Epoch 3/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.6553 - acc: 0.7910 - val_loss: 0.5195 - val_acc: 0.8417
# Epoch 4/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.5188 - acc: 0.8401 - val_loss: 0.4599 - val_acc: 0.8608
# Epoch 5/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.4579 - acc: 0.8602 - val_loss: 0.4202 - val_acc: 0.8759
# Epoch 6/500
# 60000/60000 [==============================] - 0s 8us/step - loss: 0.4175 - acc: 0.8747 - val_loss: 0.3889 - val_acc: 0.8863
# Epoch 7/500
# ...

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_6')

# %%
from keras.layers.normalization import BatchNormalization
model = Sequential()
model.add(Dense(1000, input_dim=num_pixels, kernel_initializer='zeros',activation='relu'))
model.add(Dense(500,  kernel_initializer='zeros',activation='relu'))
model.add(Dense(250,  kernel_initializer='zeros',activation='relu'))
model.add(Dense(100,  kernel_initializer='zeros',activation='relu'))
model.add(Dense(num_classes,  activation='softmax'))
# Compile model
adam = Adam(lr=0.001)
tensorboard = TensorBoard(log_dir = "logs/tensor_7")
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1000, batch_size=60000, verbose=1,callbacks=[tensorboard])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1000
# 60000/60000 [==============================] - 2s 29us/step - loss: 2.6586 - acc: 0.1076 - val_loss: 1.5583 - val_acc: 0.6081
# Epoch 2/1000
# 60000/60000 [==============================] - 0s 8us/step - loss: 2.1970 - acc: 0.2333 - val_loss: 1.0853 - val_acc: 0.7260
# Epoch 3/1000
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.7965 - acc: 0.3842 - val_loss: 0.8635 - val_acc: 0.7685
# Epoch 4/1000
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.5005 - acc: 0.4957 - val_loss: 0.7419 - val_acc: 0.7904
# Epoch 5/1000
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.2881 - acc: 0.5759 - val_loss: 0.6599 - val_acc: 0.8101
# Epoch 6/1000
# 60000/60000 [==============================] - 0s 7us/step - loss: 1.1251 - acc: 0.6297 - val_loss: 0.6019 - val_acc: 0.8236
# Epoch 7/1000
# ...

# %%
from google.datalab.ml import TensorBoard as tb
tb.start('./logs/tensor_7')

# %%
from keras.layers.normalization import BatchNormalization
model = Sequential()
model.add(Dense(1000, input_dim=num_pixels, kernel_initializer='normal',activation='tanh'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(500,  kernel_initializer='normal',activation='tanh'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(250,  kernel_initializer='normal',activation='tanh'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
model.add(Dense(100,  kernel_initializer='normal',activation='tanh'))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# model.add(Dropout(0.5))
# model.add(Dense(500,kernel_initializer='normal',kernel_regularizer=l2(0.01),activation='tanh'))
# #model.add(Dropout(0.5))
# model.add(Dense(250,kernel_initializer='normal',kernel_regularizer=l2(0.01),activation='tanh'))

#model.add(Dense(500,kernel_initializer=RandomUniform(minval=-100, maxval=100, seed=None),activation='relu'))

model.add(Dense(num_classes,  activation='softmax'))
# Compile model
adam = Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, batch_size=60000, verbose=1)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/500
# 60000/60000 [==============================] - 1s 11us/step - loss: 0.0631 - acc: 0.9803 - val_loss: 0.0791 - val_acc: 0.9800
# Epoch 2/500
# 60000/60000 [==============================] - 1s 10us/step - loss: 0.0656 - acc: 0.9803 - val_loss: 0.0791 - val_acc: 0.9797
# Epoch 3/500
# 60000/60000 [==============================] - 1s 10us/step - loss: 0.0645 - acc: 0.9800 - val_loss: 0.0791 - val_acc: 0.9794
# Epoch 4/500
# 60000/60000 [==============================] - 1s 10us/step - loss: 0.0664 - acc: 0.9795 - val_loss: 0.0792 - val_acc: 0.9793
# Epoch 5/500
# 60000/60000 [==============================] - 1s 9us/step - loss: 0.0653 - acc: 0.9797 - val_loss: 0.0794 - val_acc: 0.9793
# Epoch 6/500
# 60000/60000 [==============================] - 1s 9us/step - loss: 0.0649 - acc: 0.9800 - val_loss: 0.0795 - val_acc: 0.9795
# Epoch 7/500
# ...
